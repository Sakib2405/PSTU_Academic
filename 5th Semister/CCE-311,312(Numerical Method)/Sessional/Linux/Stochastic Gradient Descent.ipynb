# %%
def stochastic_gradient_descent():
    n = int(input("Enter number of data points: "))
    x = []
    y = []
    for i in range(n):
        xi = float(input(f"Enter x[{i}]: "))
        yi = float(input(f"Enter y[{i}]: "))
        x.append(xi)
        y.append(yi)

    lr = float(input("Enter learning rate: "))
    epochs = int(input("Enter number of epochs: "))

    m = 0
    c = 0
    for _ in range(epochs):
        for i in range(n):
            y_pred = m*x[i] + c
            error = y[i] - y_pred
            m += lr * error * x[i]
            c += lr * error
    print(f"Estimated line: y = {m}x + {c}")

stochastic_gradient_descent()

# %%
def stochastic_gradient_descent():
    x = [1, 2, 3, 4, 5]
    y = [2, 4, 5, 4, 5]
    lr = 0.01
    epochs = 1000
    n = len(x)

    m = 0
    c = 0
    for _ in range(epochs):
        for i in range(n):
            y_pred = m*x[i] + c
            error = y[i] - y_pred
            m += lr * error * x[i]
            c += lr * error
    print(m, c)

stochastic_gradient_descent()
# Out:
# 0.5746913334446111 2.240509325694681
