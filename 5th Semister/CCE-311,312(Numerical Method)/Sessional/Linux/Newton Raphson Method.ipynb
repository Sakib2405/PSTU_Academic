# %%
def f(x):
    return eval(func)

def df(x):
    return eval(dfunc)

func = input("Enter the function in terms of x: ")
dfunc = input("Enter the derivative of the function in terms of x: ")
x0 = float(input("Enter initial guess: "))
tol = float(input("Enter tolerance: "))
max_iter = int(input("Enter maximum iterations: "))

for i in range(max_iter):
    x1 = x0 - f(x0)/df(x0)
    if abs(x1 - x0) < tol:
        print("Root:", x1)
        break
    x0 = x1
else:
    print("Did not converge")

# %%
## without user input

def f(x):
    return x**3 - x - 2

def df(x):
    return 3*x**2 - 1

x0 = 1.5
tol = 1e-5
max_iter = 100

for i in range(max_iter):
    x1 = x0 - f(x0)/df(x0)
    if abs(x1 - x0) < tol:
        print(x1)
        break
    x0 = x1
