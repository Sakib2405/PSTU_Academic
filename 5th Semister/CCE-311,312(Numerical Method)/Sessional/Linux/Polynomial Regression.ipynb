# %%
import numpy as np

def polynomial_regression():
    n = int(input("Enter number of data points: "))
    degree = int(input("Enter degree of polynomial: "))
    x = []
    y = []
    for i in range(n):
        xi = float(input(f"Enter x[{i}]: "))
        yi = float(input(f"Enter y[{i}]: "))
        x.append(xi)
        y.append(yi)

    coeffs = np.polyfit(x, y, degree)
    print("Polynomial coefficients:", coeffs)
    print("Polynomial equation:")
    eq = "y = "
    for i, c in enumerate(coeffs):
        power = degree - i
        eq += f"{c}*x**{power} + " if power != 0 else f"{c}"
    print(eq)

polynomial_regression()

# %%
## without user input


import numpy as np

def polynomial_regression():
    x = [1, 2, 3, 4, 5]
    y = [1, 4, 9, 16, 25]
    degree = 2

    coeffs = np.polyfit(x, y, degree)
    print(coeffs)
    eq = "y = "
    for i, c in enumerate(coeffs):
        power = degree - i
        eq += f"{c}*x**{power} + " if power != 0 else f"{c}"
    print(eq)

polynomial_regression()
# Out:
# [ 1.00000000e+00 -2.28233685e-14  4.11031379e-14]
# y = 1.0000000000000042*x**2 + -2.2823368530424295e-14*x**1 + 4.1103137873315034e-14
